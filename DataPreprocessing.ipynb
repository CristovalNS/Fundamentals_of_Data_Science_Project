# %%
# pip install scikit-learn

# %%
import pandas as pd
import numpy as np
import re
from sklearn.impute import SimpleImputer

# %%
#Reading both CSVs and merging them
df_mar = pd.read_csv('mar22_unicorn.csv')
df_nov = pd.read_csv('nov22_unicorn.csv')
df = df_mar.merge(df_nov, left_on='Company', right_on='Company')
df.head()
# Out:
#   Company  Valuation Date Joined_x                       Industry_x  \
# 0  SpaceX        100    2012-12-01                            Other
# 1   SHEIN        100    2018-07-03  E-commerce & direct-to-consumer
# 2  Stripe         95    2014-01-23                          FinTech
# 3  Klarna         46    2011-12-12                          Fintech
# 4   Canva         40    2018-01-08     Internet software & services
#
#           City_x Country/Region      Continent  Year Founded Funding  \
# 0      Hawthorne  United States  North America          2002     $7B
# 1       Shenzhen          China           Asia          2008     $2B
# 2  San Francisco  United States  North America          2010     $2B
# 3      Stockholm         Sweden         Europe          2005     $4B
# 4    Surry Hills      Australia        Oceania          2012   $572M
#
#                                   Select Investors_x  Unnamed: 0  \
# 0  Founders Fund, Draper Fisher Jurvetson, Rothen...           1
# 1  Tiger Global Management, Sequoia Capital China...           2
# 2        Khosla Ventures, LowercaseCapital, capitalG           3
# 3  Institutional Venture Partners, Sequoia Capita...          98
# 4  Sequoia Capital China, Blackbird Ventures, Mat...           4
#
#   Valuation ($B) Date Joined_y        Country         City_y  \
# 0           $127     12/1/2012  United States      Hawthorne
# 1           $100      7/3/2018          China       Shenzhen
# 2            $95     1/23/2014  United States  San Francisco
# 3           $6.7    12/12/2011         Sweden      Stockholm
# 4            $40      1/8/2018      Australia    Surry Hills
#
#                         Industry_y  \
# 0                            Other
# 1  E-commerce & direct-to-consumer
# 2                          Fintech
# 3                          Fintech
# 4     Internet software & services
#
#                                   Select Investors_y
# 0  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 1  Tiger Global Management, Sequoia Capital China...
# 2        Khosla Ventures, LowercaseCapital, capitalG
# 3  Institutional Venture Partners, Sequoia Capita...
# 4  Sequoia Capital China, Blackbird Ventures, Mat...

# %%
#Combining duplicate data
df['Date Joined'] = np.where(df['Date Joined_x'] is None, df['Date Joined_y'], df['Date Joined_x'])
df['Industry'] = np.where(df['Industry_x'] is None, df['Industry_y'], df['Industry_x'])
df['City'] = np.where(df['City_x'] is None, df['City_y'], df['City_x'])
df['Country'] = np.where(df['Country'] is None, df['Country/Region'], df['Country'])

#Renaming valuation for both tables and converting numbers to int
df['Valuation ($B)'].replace('[$]', '', regex=True, inplace=True)
df['Valuation (November) ($B)'] = df['Valuation ($B)'].apply(float)
df['Valuation (March) ($B)'] = df['Valuation']

# %%
#Slicing and removing unused data
df = df[['Company','Date Joined',
       'Industry', 'Country', 'City', 'Continent', 'Year Founded', 'Funding',
       'Valuation (March) ($B)', 'Select Investors_x', 'Valuation (November) ($B)', 'Select Investors_y']]
df.rename(columns = {'Select Investors_x': 'Select Investors (March)', 'Select Investors_y': 'Select Investors (November)'}, inplace = True)
df.head()
# Out:
#   Company Date Joined                         Industry        Country  \
# 0  SpaceX  2012-12-01                            Other  United States
# 1   SHEIN  2018-07-03  E-commerce & direct-to-consumer          China
# 2  Stripe  2014-01-23                          FinTech  United States
# 3  Klarna  2011-12-12                          Fintech         Sweden
# 4   Canva  2018-01-08     Internet software & services      Australia
#
#             City      Continent  Year Founded Funding  Valuation (March) ($B)  \
# 0      Hawthorne  North America          2002     $7B                     100
# 1       Shenzhen           Asia          2008     $2B                     100
# 2  San Francisco  North America          2010     $2B                      95
# 3      Stockholm         Europe          2005     $4B                      46
# 4    Surry Hills        Oceania          2012   $572M                      40
#
#                             Select Investors (March)  \
# 0  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 1  Tiger Global Management, Sequoia Capital China...
# 2        Khosla Ventures, LowercaseCapital, capitalG
# 3  Institutional Venture Partners, Sequoia Capita...
# 4  Sequoia Capital China, Blackbird Ventures, Mat...
#
#    Valuation (November) ($B)  \
# 0                      127.0
# 1                      100.0
# 2                       95.0
# 3                        6.7
# 4                       40.0
#
#                          Select Investors (November)
# 0  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 1  Tiger Global Management, Sequoia Capital China...
# 2        Khosla Ventures, LowercaseCapital, capitalG
# 3  Institutional Venture Partners, Sequoia Capita...
# 4  Sequoia Capital China, Blackbird Ventures, Mat...

# %%
df['Years to Unicorn'] = df['Date Joined'].apply(lambda x: int(x[:4])) - df['Year Founded']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1039 entries, 0 to 1038
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Company                      1039 non-null   object
#  1   Date Joined                  1039 non-null   object
#  2   Industry                     1039 non-null   object
#  3   Country                      1039 non-null   object
#  4   City                         1022 non-null   object
#  5   Continent                    1039 non-null   object
#  6   Year Founded                 1039 non-null   int64
#  7   Funding                      1039 non-null   object
#  8   Valuation (March) ($B)       1039 non-null   int64
#  9   Select Investors (March)     1039 non-null   object
#  10  Valuation (November) ($B)    1039 non-null   float64
#  11  Select Investors (November)  1038 non-null   object
#  12  Years to Unicorn             1039 non-null   int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 105.6+ KB

# %%
df['Most Recent Valuation'] = np.where(df['Valuation (November) ($B)'] is None, df['Valuation (March) ($B)'], df['Valuation (November) ($B)'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1039 entries, 0 to 1038
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Company                      1039 non-null   object
#  1   Date Joined                  1039 non-null   object
#  2   Industry                     1039 non-null   object
#  3   Country                      1039 non-null   object
#  4   City                         1022 non-null   object
#  5   Continent                    1039 non-null   object
#  6   Year Founded                 1039 non-null   int64
#  7   Funding                      1039 non-null   object
#  8   Valuation (March) ($B)       1039 non-null   int64
#  9   Select Investors (March)     1039 non-null   object
#  10  Valuation (November) ($B)    1039 non-null   float64
#  11  Select Investors (November)  1038 non-null   object
#  12  Years to Unicorn             1039 non-null   int64
#  13  Most Recent Valuation        1039 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 113.8+ KB

# %%
df['Industry'] = df['Industry'].apply(lambda x: ' '.join(word.capitalize() for word in x.split()))
df['Industry'] = df['Industry'].replace('&', 'And', regex=True)
df['Industry'].unique()
# Out:
# array(['Other', 'E-commerce And Direct-to-consumer', 'Fintech',
#        'Internet Software And Services',
#        'Supply Chain, Logistics, And Delivery', 'Consumer And Retail',
#        'Data Management And Analytics', 'Edtech', 'Health',
#        'Artificial Intelligence', 'Auto And Transportation', 'Hardware',
#        'Travel', 'Cybersecurity', 'Mobile And Telecommunications'],
#       dtype=object)

# %%
# df.to_csv('new_unicorn_data.csv')

# %%
# Define a function to extract numeric values
def extract_numeric_value(value):
    match = re.search(r'\$(\d+(\.\d+)?)([BM]?)', str(value))
    if match:
        number = float(match.group(1))
        suffix = match.group(3)
        if suffix == 'B':
            number = int(number) if number.is_integer() else round(number, 3)
        elif suffix == 'M':
            number *= 0.001 
        return number
    else:
        return None

# Applying the function to convert the values in Funding
df['Funding_Numeric ($B)'] = df['Funding'].apply(extract_numeric_value)

# Calculate the mean of the numeric values
mean_value = df['Funding_Numeric ($B)'].mean()

# Use SimpleImputer to replace NaN values with the mean
imputer = SimpleImputer(strategy='constant', fill_value=mean_value)
df['Funding_Numeric ($B)'] = imputer.fit_transform(df[['Funding_Numeric ($B)']])

df["Funding_Numeric ($B)"].head()
# Out:
# 0    7.000
# 1    2.000
# 2    2.000
# 3    4.000
# 4    0.572
# Name: Funding_Numeric ($B), dtype: float64

# %%
df.head()
# Out:
#   Company Date Joined                           Industry        Country  \
# 0  SpaceX  2012-12-01                              Other  United States
# 1   SHEIN  2018-07-03  E-commerce And Direct-to-consumer          China
# 2  Stripe  2014-01-23                            Fintech  United States
# 3  Klarna  2011-12-12                            Fintech         Sweden
# 4   Canva  2018-01-08     Internet Software And Services      Australia
#
#             City      Continent  Year Founded Funding  Valuation (March) ($B)  \
# 0      Hawthorne  North America          2002     $7B                     100
# 1       Shenzhen           Asia          2008     $2B                     100
# 2  San Francisco  North America          2010     $2B                      95
# 3      Stockholm         Europe          2005     $4B                      46
# 4    Surry Hills        Oceania          2012   $572M                      40
#
#                             Select Investors (March)  \
# 0  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 1  Tiger Global Management, Sequoia Capital China...
# 2        Khosla Ventures, LowercaseCapital, capitalG
# 3  Institutional Venture Partners, Sequoia Capita...
# 4  Sequoia Capital China, Blackbird Ventures, Mat...
#
#    Valuation (November) ($B)  \
# 0                      127.0
# 1                      100.0
# 2                       95.0
# 3                        6.7
# 4                       40.0
#
#                          Select Investors (November)  Years to Unicorn  \
# 0  Founders Fund, Draper Fisher Jurvetson, Rothen...                10
# 1  Tiger Global Management, Sequoia Capital China...                10
# 2        Khosla Ventures, LowercaseCapital, capitalG                 4
# 3  Institutional Venture Partners, Sequoia Capita...                 6
# 4  Sequoia Capital China, Blackbird Ventures, Mat...                 6
#
#    Most Recent Valuation  Funding_Numeric ($B)
# 0                  127.0                 7.000
# 1                  100.0                 2.000
# 2                   95.0                 2.000
# 3                    6.7                 4.000
# 4                   40.0                 0.572

# %%
# Move 'Funding_Numeric' next to 'Funding'
columns = list(df.columns)

columns.insert(columns.index('Funding') + 1, columns.pop(columns.index('Funding_Numeric ($B)')))

df = df[columns]

# Save the DataFrame back to a CSV file
df.to_csv('new_unicorn_data_updated.csv', index=False)

# %%
df.head()
# Out:
#   Company Date Joined                           Industry        Country  \
# 0  SpaceX  2012-12-01                              Other  United States
# 1   SHEIN  2018-07-03  E-commerce And Direct-to-consumer          China
# 2  Stripe  2014-01-23                            Fintech  United States
# 3  Klarna  2011-12-12                            Fintech         Sweden
# 4   Canva  2018-01-08     Internet Software And Services      Australia
#
#             City      Continent  Year Founded Funding  Funding_Numeric ($B)  \
# 0      Hawthorne  North America          2002     $7B                 7.000
# 1       Shenzhen           Asia          2008     $2B                 2.000
# 2  San Francisco  North America          2010     $2B                 2.000
# 3      Stockholm         Europe          2005     $4B                 4.000
# 4    Surry Hills        Oceania          2012   $572M                 0.572
#
#    Valuation (March) ($B)                           Select Investors (March)  \
# 0                     100  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 1                     100  Tiger Global Management, Sequoia Capital China...
# 2                      95        Khosla Ventures, LowercaseCapital, capitalG
# 3                      46  Institutional Venture Partners, Sequoia Capita...
# 4                      40  Sequoia Capital China, Blackbird Ventures, Mat...
#
#    Valuation (November) ($B)  \
# 0                      127.0
# 1                      100.0
# 2                       95.0
# 3                        6.7
# 4                       40.0
#
#                          Select Investors (November)  Years to Unicorn  \
# 0  Founders Fund, Draper Fisher Jurvetson, Rothen...                10
# 1  Tiger Global Management, Sequoia Capital China...                10
# 2        Khosla Ventures, LowercaseCapital, capitalG                 4
# 3  Institutional Venture Partners, Sequoia Capita...                 6
# 4  Sequoia Capital China, Blackbird Ventures, Mat...                 6
#
#    Most Recent Valuation
# 0                  127.0
# 1                  100.0
# 2                   95.0
# 3                    6.7
# 4                   40.0

# %%
# Test: Filter rows where Funding_Numeric is less than 1
filtered_df = df[df['Funding_Numeric ($B)'] < 1]
print(filtered_df)
# Out:
#           Company Date Joined                           Industry  \
# 4           Canva  2018-01-08     Internet Software And Services
# 16    Xiaohongshu  2016-03-31  E-commerce And Direct-to-consumer
# 17           Miro  2022-01-05     Internet Software And Services
# 19          Rapyd  2019-12-03                            Fintech
# 20        Discord  2018-04-20     Internet Software And Services
# ...           ...         ...                                ...
# 1034     Zhaogang  2017-06-29  E-commerce And Direct-to-consumer
# 1035  Zhuan Zhuan  2017-04-18  E-commerce And Direct-to-consumer
# 1036     Zihaiguo  2021-05-06                Consumer And Retail
# 1037         Zopa  2021-10-19                            Fintech
# 1038        Zwift  2020-09-16  E-commerce And Direct-to-consumer
#
#              Country           City      Continent  Year Founded Funding  \
# 4          Australia    Surry Hills        Oceania          2012   $572M
# 16             China       Shanghai           Asia          2013   $918M
# 17     United States  San Francisco  North America          2011   $476M
# 19    United Kingdom         London         Europe          2016   $770M
# 20     United States  San Francisco  North America          2012   $979M
# ...              ...            ...            ...           ...     ...
# 1034           China       Shanghai           Asia          2012   $379M
# 1035           China        Beijing           Asia          2015   $990M
# 1036           China      Chongqing           Asia          2018    $80M
# 1037  United Kingdom         London         Europe          2005   $792M
# 1038   United States     Long Beach  North America          2014   $620M
#
#       Funding_Numeric ($B)  Valuation (March) ($B)  \
# 4                    0.572                      40
# 16                   0.918                      20
# 17                   0.476                      18
# 19                   0.770                      15
# 20                   0.979                      15
# ...                    ...                     ...
# 1034                 0.379                       1
# 1035                 0.990                       1
# 1036                 0.080                       1
# 1037                 0.792                       1
# 1038                 0.620                       1
#
#                                Select Investors (March)  \
# 4     Sequoia Capital China, Blackbird Ventures, Mat...
# 16                       GGV Capital, ZhenFund, Tencent
# 17    Accel, AltaIR Capital, Technology Crossover Ve...
# 19    Target Global, General Catalyst, Durable Capit...
# 20       Benchmark, Greylock Partners, Tencent Holdings
# ...                                                 ...
# 1034    K2 Ventures, Matrix Partners China, IDG Capital
# 1035                           58.com, Tencent Holdings
# 1036  Xingwang Investment Management, China Capital ...
# 1037  IAG Capital Partners, Augmentum Fintech, North...
# 1038    Novator Partners, True, Causeway Media Partners
#
#       Valuation (November) ($B)  \
# 4                         40.00
# 16                        20.00
# 17                        17.50
# 19                         8.75
# 20                        15.00
# ...                         ...
# 1034                       1.00
# 1035                       1.00
# 1036                       1.00
# 1037                       1.00
# 1038                       1.00
#
#                             Select Investors (November)  Years to Unicorn  \
# 4     Sequoia Capital China, Blackbird Ventures, Mat...                 6
# 16                       GGV Capital, ZhenFund, Tencent                 3
# 17    Accel, AltaIR Capital, Technology Crossover Ve...                11
# 19    Target Global, General Catalyst, Durable Capit...                 3
# 20       Benchmark, Greylock Partners, Tencent Holdings                 6
# ...                                                 ...               ...
# 1034    K2 Ventures, Matrix Partners China, IDG Capital                 5
# 1035                           58.com, Tencent Holdings                 2
# 1036  Xingwang Investment Management, China Capital ...                 3
# 1037  IAG Capital Partners, Augmentum Fintech, North...                16
# 1038    Novator Partners, True, Causeway Media Partners                 6
#
#       Most Recent Valuation
# 4                     40.00
# 16                    20.00
# 17                    17.50
# 19                     8.75
# 20                    15.00
# ...                     ...
# 1034                   1.00
# 1035                   1.00
# 1036                   1.00
# 1037                   1.00
# 1038                   1.00
#
# [930 rows x 15 columns]
